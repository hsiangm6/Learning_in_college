# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_A=pd.read_csv("糖尿病相關資料集/實驗A/train_data.csv")
test_A=pd.read_csv("糖尿病相關資料集/實驗A/test_data.csv")
train_B=pd.read_csv("糖尿病相關資料集/實驗B/train_data.csv")
test_B=pd.read_csv("糖尿病相關資料集/實驗B/test_data.csv")

col_len=len(train_A.columns)-1

def euclideanDistance(train, test, row, length):
    distance=0
    for col in range(length):
        distance+=(train.iloc[row][col]-test.iloc[row][col])

display(train_A)
print(train_A.iloc[0,1])
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 562            1       87             68             34       77  37.6
# 563            6       99             60             19       54  26.9
# 564            0       91             80              0        0  32.4
# 565            2       95             54             14       88  26.1
# 566            1       99             72             30       18  38.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 562                     0.401   24        0
# 563                     0.497   32        0
# 564                     0.601   27        0
# 565                     0.748   22        0
# 566                     0.412   21        0
#
# [567 rows x 9 columns]
# 148
